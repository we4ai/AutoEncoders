# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import torch
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
import cv2
np.set_printoptions(threshold=np.inf)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.
use_cuda=torch.cuda.is_available()
use_cuda

# %%
# !ls ../input/flickr-image-dataset/flickr30k_images/flickr30k_images/flickr30k_images/

# %%
# !mkdir ../working/flickr_sample

# %%
# !find ../input/flickr-image-dataset/flickr30k_images/flickr30k_images/flickr30k_images/  -maxdepth 1 -type f | head -1000 | xargs cp -t ../working/flickr_sample
# Out:
# find: ‘standard output’: Broken pipe
# find: write error

# %%
image_size=300
transform=transforms.Compose([
        transforms.Resize((image_size,image_size)),
#         transforms.RandomRotation(degrees=15),
#         transforms.ColorJitter(),
#         transforms.RandomHorizontalFlip(),
#         transforms.CenterCrop(size=224),  # Image net standards
        transforms.ToTensor()
#         transforms.Normalize([0.485, 0.456, 0.406],
#                              [0.229, 0.224, 0.225])  # Imagenet standards
    ])
path=str('../working/')

# load the data using ImageFolder
data = datasets.ImageFolder(root=path,transform=transform)

num_workers = 0
batch_size = 50

data_loader = torch.utils.data.DataLoader(data, batch_size=batch_size, num_workers=num_workers,shuffle=True)
print(len(data_loader))
data
# Out:
# 20
# Dataset ImageFolder
#     Number of datapoints: 1000
#     Root location: ../working/
#     StandardTransform
# Transform: Compose(
#                Resize(size=(300, 300), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#            )

# %%
data_loader

# %%
dataiter = iter(data_loader)
images,_ = dataiter.next()
images
# Out:
# tensor([[[[0.2118, 0.1333, 0.1765,  ..., 0.0980, 0.0863, 0.0745],
#           [0.1882, 0.2392, 0.2980,  ..., 0.1020, 0.1059, 0.0941],
#           [0.1569, 0.2902, 0.3490,  ..., 0.1098, 0.1137, 0.1020],
#           ...,
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0039, 0.0039, 0.0078,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0078, 0.0157, 0.0235,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.4941, 0.3059, 0.4118,  ..., 0.0471, 0.0431, 0.0314],
#           [0.4863, 0.4980, 0.5647,  ..., 0.0549, 0.0510, 0.0392],
#           [0.3882, 0.5922, 0.6706,  ..., 0.0549, 0.0471, 0.0431],
#           ...,
#           [0.0039, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#
#          [[0.0118, 0.0314, 0.1804,  ..., 0.0235, 0.0235, 0.0118],
#           [0.0353, 0.0902, 0.2667,  ..., 0.0314, 0.0275, 0.0157],
#           [0.0627, 0.1216, 0.1333,  ..., 0.0314, 0.0196, 0.0118],
#           ...,
#           [0.0118, 0.0078, 0.0078,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0078, 0.0118, 0.0196,  ..., 0.0000, 0.0000, 0.0000],
#           [0.0392, 0.0471, 0.0588,  ..., 0.0000, 0.0000, 0.0000]]],
#
#
#         [[[0.2392, 0.2431, 0.2392,  ..., 0.0549, 0.0471, 0.0471],
#           [0.2196, 0.2157, 0.1922,  ..., 0.0745, 0.0667, 0.0627],
#           [0.2118, 0.2392, 0.2196,  ..., 0.0667, 0.0549, 0.0706],
#           ...,
#           [0.5569, 0.5647, 0.5451,  ..., 0.6667, 0.6863, 0.6706],
#           [0.6039, 0.6039, 0.4549,  ..., 0.6745, 0.7176, 0.6431],
#           [0.6000, 0.6392, 0.5804,  ..., 0.6667, 0.7255, 0.7216]],
#
#          [[0.2353, 0.2392, 0.2353,  ..., 0.0706, 0.0627, 0.0588],
#           [0.2118, 0.2196, 0.1961,  ..., 0.0627, 0.0549, 0.0510],
#           [0.2196, 0.2353, 0.2078,  ..., 0.0784, 0.0627, 0.0706],
#           ...,
#           [0.4039, 0.4196, 0.3961,  ..., 0.5294, 0.5608, 0.5412],
#           [0.4784, 0.4745, 0.3373,  ..., 0.5451, 0.6078, 0.5333],
#           [0.4706, 0.4902, 0.4627,  ..., 0.5412, 0.6078, 0.6000]],
#
#          [[0.2118, 0.2039, 0.2000,  ..., 0.0549, 0.0549, 0.0627],
#           [0.1725, 0.1922, 0.1647,  ..., 0.0667, 0.0588, 0.0588],
#           [0.2000, 0.2118, 0.1922,  ..., 0.0706, 0.0706, 0.0824],
#           ...,
#           [0.3098, 0.3098, 0.2941,  ..., 0.4078, 0.4431, 0.4353],
#           [0.3686, 0.3608, 0.2510,  ..., 0.4275, 0.4941, 0.4000],
#           [0.3647, 0.3882, 0.3608,  ..., 0.4275, 0.4980, 0.4784]]],
#
#
#         [[[0.1843, 0.2157, 0.2118,  ..., 0.0980, 0.1020, 0.0863],
#           [0.2000, 0.2314, 0.2275,  ..., 0.1059, 0.1098, 0.0941],
#           [0.2000, 0.2353, 0.2314,  ..., 0.1098, 0.1137, 0.0980],
#           ...,
#           [0.4941, 0.6471, 0.6235,  ..., 0.2196, 0.2235, 0.2196],
#           [0.5098, 0.6314, 0.6941,  ..., 0.2196, 0.2824, 0.3098],
#           [0.4745, 0.5490, 0.5176,  ..., 0.3059, 0.3804, 0.3765]],
#
#          [[0.1725, 0.2039, 0.2000,  ..., 0.1059, 0.1059, 0.0863],
#           [0.1882, 0.2196, 0.2157,  ..., 0.1098, 0.1098, 0.0902],
#           [0.1882, 0.2235, 0.2196,  ..., 0.1059, 0.1098, 0.0941],
#           ...,
#           [0.5098, 0.6510, 0.6275,  ..., 0.2039, 0.2118, 0.2157],
#           [0.5176, 0.6392, 0.6980,  ..., 0.2314, 0.3059, 0.3333],
#           [0.4863, 0.5608, 0.5255,  ..., 0.3373, 0.4196, 0.4118]],
#
#          [[0.1529, 0.1725, 0.1647,  ..., 0.0941, 0.0980, 0.0824],
#           [0.1647, 0.1882, 0.1804,  ..., 0.0980, 0.1020, 0.0824],
#           [0.1608, 0.1882, 0.1843,  ..., 0.0980, 0.0980, 0.0784],
#           ...,
#           [0.4784, 0.6314, 0.6118,  ..., 0.2275, 0.2431, 0.2471],
#           [0.4863, 0.6157, 0.6824,  ..., 0.2784, 0.3529, 0.3765],
#           [0.4549, 0.5333, 0.5059,  ..., 0.3843, 0.4588, 0.4431]]],
#
#
#         ...,
#
#
#         [[[0.5569, 0.5843, 0.4667,  ..., 0.8078, 0.8118, 0.8078],
#           [0.5176, 0.5686, 0.4824,  ..., 0.8078, 0.8157, 0.8157],
#           [0.5529, 0.5451, 0.5020,  ..., 0.8157, 0.8078, 0.8118],
#           ...,
#           [0.4510, 0.4471, 0.4235,  ..., 0.3490, 0.3490, 0.3412],
#           [0.4157, 0.3725, 0.3922,  ..., 0.3412, 0.3373, 0.3412],
#           [0.3020, 0.3294, 0.3804,  ..., 0.3216, 0.3373, 0.3255]],
#
#          [[0.5412, 0.5725, 0.4471,  ..., 0.8000, 0.7961, 0.7843],
#           [0.5059, 0.5529, 0.4549,  ..., 0.8078, 0.8235, 0.8118],
#           [0.5451, 0.5255, 0.4824,  ..., 0.8118, 0.8118, 0.8078],
#           ...,
#           [0.3961, 0.3843, 0.3686,  ..., 0.3451, 0.3451, 0.3373],
#           [0.3765, 0.3176, 0.3333,  ..., 0.3333, 0.3294, 0.3451],
#           [0.2706, 0.2824, 0.3176,  ..., 0.3098, 0.3255, 0.3216]],
#
#          [[0.3961, 0.4235, 0.2980,  ..., 0.7098, 0.7059, 0.6980],
#           [0.3647, 0.4039, 0.3059,  ..., 0.7255, 0.7373, 0.7294],
#           [0.4039, 0.3725, 0.3216,  ..., 0.7333, 0.7294, 0.7294],
#           ...,
#           [0.2353, 0.2157, 0.1843,  ..., 0.2627, 0.2667, 0.2588],
#           [0.2118, 0.1412, 0.1451,  ..., 0.2510, 0.2510, 0.2588],
#           [0.1059, 0.0941, 0.1216,  ..., 0.2314, 0.2471, 0.2353]]],
#
#
#         [[[0.9686, 0.9686, 0.9725,  ..., 0.6784, 0.7569, 0.7020],
#           [0.9608, 0.9569, 0.9725,  ..., 0.6510, 0.7843, 0.8745],
#           [0.9922, 0.9843, 0.9882,  ..., 0.6980, 0.7647, 0.8275],
#           ...,
#           [0.5176, 0.5176, 0.5176,  ..., 0.3725, 0.3843, 0.4000],
#           [0.5176, 0.5176, 0.5176,  ..., 0.3686, 0.4000, 0.3686],
#           [0.5176, 0.5216, 0.5216,  ..., 0.3647, 0.3765, 0.3843]],
#
#          [[0.9686, 0.9686, 0.9725,  ..., 0.6706, 0.7686, 0.7020],
#           [0.9608, 0.9569, 0.9725,  ..., 0.6353, 0.7922, 0.8745],
#           [0.9922, 0.9843, 0.9882,  ..., 0.6784, 0.7647, 0.8314],
#           ...,
#           [0.2196, 0.2196, 0.2196,  ..., 0.3647, 0.3765, 0.3922],
#           [0.2196, 0.2196, 0.2196,  ..., 0.3569, 0.3882, 0.3569],
#           [0.2196, 0.2235, 0.2235,  ..., 0.3529, 0.3647, 0.3725]],
#
#          [[0.9686, 0.9686, 0.9725,  ..., 0.6980, 0.7725, 0.7216],
#           [0.9608, 0.9569, 0.9725,  ..., 0.6706, 0.8078, 0.8941],
#           [0.9922, 0.9843, 0.9882,  ..., 0.7137, 0.7843, 0.8471],
#           ...,
#           [0.0824, 0.0902, 0.0784,  ..., 0.3451, 0.3569, 0.3725],
#           [0.0824, 0.0902, 0.0824,  ..., 0.3373, 0.3686, 0.3373],
#           [0.0824, 0.0941, 0.0863,  ..., 0.3333, 0.3451, 0.3529]]],
#
#
#         [[[0.7765, 0.7804, 0.7765,  ..., 0.8275, 0.8471, 0.8275],
#           [0.8000, 0.7804, 0.7647,  ..., 0.8196, 0.8157, 0.8235],
#           [0.6980, 0.7569, 0.7882,  ..., 0.8314, 0.8314, 0.8431],
#           ...,
#           [0.5255, 0.5373, 0.5608,  ..., 0.6196, 0.6353, 0.6314],
#           [0.5373, 0.5373, 0.5373,  ..., 0.5882, 0.6235, 0.6353],
#           [0.5216, 0.5529, 0.5686,  ..., 0.5529, 0.5882, 0.5961]],
#
#          [[0.8980, 0.9020, 0.9098,  ..., 0.8392, 0.8588, 0.8353],
#           [0.9020, 0.9098, 0.9216,  ..., 0.8314, 0.8275, 0.8314],
#           [0.8275, 0.8863, 0.9176,  ..., 0.8431, 0.8431, 0.8510],
#           ...,
#           [0.5294, 0.5412, 0.5569,  ..., 0.6039, 0.6157, 0.6078],
#           [0.5412, 0.5373, 0.5255,  ..., 0.5647, 0.5961, 0.6000],
#           [0.5059, 0.5412, 0.5608,  ..., 0.5255, 0.5412, 0.5529]],
#
#          [[0.9922, 0.9882, 0.9843,  ..., 0.7961, 0.8118, 0.7804],
#           [0.9922, 0.9882, 0.9843,  ..., 0.7961, 0.7843, 0.7765],
#           [0.9373, 0.9647, 0.9725,  ..., 0.8118, 0.8039, 0.8039],
#           ...,
#           [0.4706, 0.4902, 0.5098,  ..., 0.5137, 0.5255, 0.4980],
#           [0.4863, 0.5020, 0.4980,  ..., 0.4588, 0.5098, 0.4863],
#           [0.4392, 0.4980, 0.5216,  ..., 0.4275, 0.4588, 0.4314]]]])

# %%
# gray_image = cv2.cvtColor(images[0].numpy().transpose((1,2,0)), cv2.COLOR_RGB2GRAY)
# gray_image

# %%
def func_imshow(image, ax=None, title=None, normalize=True,gray=False):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    if gray is True:
        ax.imshow(np.dot(image[...,:3], [0.299, 0.587, 0.114]),cmap='gray')
    else:
        ax.imshow(image)
        
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

# %% [markdown]
# ## Input Image

# %%
images, labels = next(iter(data_loader))
plot = func_imshow(images[0], normalize=False)

# %% [markdown]
# ## Target Image

# %%
plot = func_imshow(images[0], normalize=False,gray=True)

# %% [markdown]
# ## Defining AutoEncoder

# %%
import torch.nn as nn
import torch.nn.functional as F

class AutoEncoder(nn.Module):
    def __init__(self):
        super(AutoEncoder, self).__init__()
        ## encoder layers ##
        self.conv1 = nn.Conv2d(3, 128 , 3, padding=1)  
        self.conv2 = nn.Conv2d(128, 32, 3, padding=1)
        self.conv3 = nn.Conv2d(32, 8, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        
        ## decoder layers ##
        self.t_conv1 = nn.ConvTranspose2d(8, 8, 3, stride=2) 
        self.t_conv2 = nn.ConvTranspose2d(8, 32, 2, stride=2)
        self.t_conv3 = nn.ConvTranspose2d(32, 128, 2, stride=2)
        self.conv_out = nn.Conv2d(128, 1, 3, padding=1)


    def forward(self, x):
        ## encode ##
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = F.relu(self.conv2(x))
        x = self.pool(x)
        x = F.relu(self.conv3(x))
        x = self.pool(x)
        
        ## decode ##
        x = F.relu(self.t_conv1(x))
        x = F.relu(self.t_conv2(x))
        x = F.relu(self.t_conv3(x))
        x = F.sigmoid(self.conv_out(x))
                
        return x

# initialize the NN
model = AutoEncoder()
if use_cuda:
    model.cuda()
print(model)
# Out:
# AutoEncoder(
#   (conv1): Conv2d(3, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (t_conv1): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(2, 2))
#   (t_conv2): ConvTranspose2d(8, 32, kernel_size=(2, 2), stride=(2, 2))
#   (t_conv3): ConvTranspose2d(32, 128, kernel_size=(2, 2), stride=(2, 2))
#   (conv_out): Conv2d(128, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
# specify loss function
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# number of epochs to train the model
n_epochs = 30

# %%
for epoch in range(1, n_epochs+1):
    # monitor training loss
    data_loss = 0.0
    
    ###################
    # train the model #
    ###################
    for data in data_loader:
        # _ stands in for labels, here
        images, _ = data
        if use_cuda:
            images=images.cuda()
        
        ## Converting Image to grayscale
        gray_image = torch.tensor([cv2.cvtColor(i.cpu().numpy().transpose((1,2,0)), cv2.COLOR_RGB2GRAY) for i in images])
        
        if use_cuda:
            gray_image=gray_image.cuda()
        optimizer.zero_grad()
        
        outputs = model(images)

        loss = criterion(outputs, gray_image.reshape(-1,1,image_size,image_size))
        loss.backward()
        optimizer.step()
        data_loss += loss.item()*images.size(0)
            
    data_loss = data_loss/len(data_loader)
    print('Epoch: {} \tTraining Loss: {:.6f}'.format(
        epoch, 
        data_loss
        ))
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch: 1 	Training Loss: 3.595931
# Epoch: 2 	Training Loss: 2.141668
# Epoch: 3 	Training Loss: 0.887598
# Epoch: 4 	Training Loss: 0.653133
# Epoch: 5 	Training Loss: 0.551985
# Epoch: 6 	Training Loss: 0.498534
# Epoch: 7 	Training Loss: 0.466879
# Epoch: 8 	Training Loss: 0.443158
# Epoch: 9 	Training Loss: 0.425710
# Epoch: 10 	Training Loss: 0.428113
# Epoch: 11 	Training Loss: 0.401844
# Epoch: 12 	Training Loss: 0.388246
# Epoch: 13 	Training Loss: 0.377158
# Epoch: 14 	Training Loss: 0.370813
# Epoch: 15 	Training Loss: 0.363863
# Epoch: 16 	Training Loss: 0.358572
# Epoch: 17 	Training Loss: 0.356220
# Epoch: 18 	Training Loss: 0.350343
# Epoch: 19 	Training Loss: 0.345405
# Epoch: 20 	Training Loss: 0.342875
# Epoch: 21 	Training Loss: 0.341471
# Epoch: 22 	Training Loss: 0.334652
# Epoch: 23 	Training Loss: 0.336659
# Epoch: 24 	Training Loss: 0.336643
# Epoch: 25 	Training Loss: 0.331565
# Epoch: 26 	Training Loss: 0.326397
# Epoch: 27 	Training Loss: 0.323821
# Epoch: 28 	Training Loss: 0.322512
# Epoch: 29 	Training Loss: 0.320308
# Epoch: 30 	Training Loss: 0.322115

# %%
torch.save(model.state_dict(), '../working/model.state')

# %%
model = model(images)
model.load_state_dict(torch.load('../working/model.state'))

# %%
# dataiter = iter(data_loader)
# images, labels = dataiter.next()


# # get sample outputs
# output = model(images[0].cuda())
# # prep images for display
# images = images.numpy()

# # output is resized into a batch of iages
# output = output.view(batch_size, 1, 300, 300)
# output = output.cpu().detach().numpy()

# %%
img = cv2.imread(image_path) 
  
# Change the current directory  
# to specified directory  
os.chdir(directory) 
  
# List files and directories   
# in 'C:/Users/Rajnish/Desktop/GeeksforGeeks'   
print("Before saving image:")   
print(os.listdir(directory))   
  
# Filename 
filename = 'savedImage.jpg'
  
# Using cv2.imwrite() method 
# Saving the image 
cv2.imwrite(filename, img)
